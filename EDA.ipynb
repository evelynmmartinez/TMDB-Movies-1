# %%
#imports
import pandas as pd

# %%
df_00 = pd.read_csv('Data/final_tmdb_data_2000.csv.gz')
df_00.head()
# Out:
#      imdb_id  adult                     backdrop_path  belongs_to_collection  \
# 0          0    NaN                               NaN                    NaN
# 1  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg                    NaN
# 2  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg                    NaN
# 3  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg                    NaN
# 4  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg                    NaN
#
#        budget                                             genres  \
# 0         NaN                                                NaN
# 1  50000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 2  50000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 3  50000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 4  50000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
#
#                            homepage        id original_language  \
# ...

# %%
df_01 = pd.read_csv('Data/final_tmdb_data_2001.csv.gz')
df_01.head()
# Out:
#      imdb_id  adult                     backdrop_path  belongs_to_collection  \
# 0          0    NaN                               NaN                    NaN
# 1  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg                    NaN
# 2  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg                    NaN
# 3  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg                    NaN
# 4  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg                    NaN
#
#        budget                                             genres  \
# 0         NaN                                                NaN
# 1  50000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 2  50000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 3  50000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 4  50000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
#
#                            homepage        id original_language  \
# ...

# %%
dfs = [df_00,df_01]
df1 = pd.concat(dfs,ignore_index = True)

# %% [markdown]
# 1. How many movies had at least some valid financial information (values > 0 for budget OR revenue)?

# %%
budget_over_zero = df1[(df1['budget'] > 0) | (df1['revenue']>0)]
movies_required_budget =len(budget_over_zero)
print("Amount of movies that had at least some valid financial information (values > 0 for budget OR revenue",movies_required_budget)
# Out:
# Amount of movies that had at least some valid financial information (values > 0 for budget OR revenue 3061

# %% [markdown]
# 2. How many movies are there in each of the certification categories (G/PG/PG-13/R)?

# %%
certifications = df1['certification'].value_counts()
print("Movies in each certification category:" , certifications)
print(certifications)
# Out:
# Movies in each certification category: R          654
# PG-13      257
# NR         173
# PG         106
# G           56
# NC-17       12
# Unrated      1
# Name: certification, dtype: int64
# R          654
# PG-13      257
# NR         173
# PG         106
# G           56
# NC-17       12
# Unrated      1
# Name: certification, dtype: int64

# %% [markdown]
# 3. What is the average revenue per certification category?

# %%
avg_rev_by_certification = df1.groupby('certification')['revenue'].mean()
print("Avg revenue per certification category:")
print(avg_rev_by_certification)
# Out:
# Avg revenue per certification category:
# certification
# G          136536687.0
# NC-17      136536687.0
# NR         136536687.0
# PG         136536687.0
# PG-13      136536687.0
# R          136536687.0
# Unrated    136536687.0
# Name: revenue, dtype: float64

# %% [markdown]
# 4. What is the average budget per certification category?

# %%
avg_budget_by_certification = df1.groupby('certification')['budget'].mean()
print("Avg budget per certification category:")
print(avg_budget_by_certification)
# Out:
# Avg budget per certification category:
# certification
# G          50000000.0
# NC-17      50000000.0
# NR         50000000.0
# PG         50000000.0
# PG-13      50000000.0
# R          50000000.0
# Unrated    50000000.0
# Name: budget, dtype: float64

# %%
df1.to_csv("Data/tmdb_results_combined.csv.gz", compression='gzip', index=False)
df1.head()
# Out:
#      imdb_id  adult                     backdrop_path  belongs_to_collection  \
# 0          0    NaN                               NaN                    NaN
# 1  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg                    NaN
# 2  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg                    NaN
# 3  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg                    NaN
# 4  tt1361336    0.0  /9ns9463dwOeo1CK1JU2wirL5Yi1.jpg                    NaN
#
#        budget                                             genres  \
# 0         NaN                                                NaN
# 1  50000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 2  50000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 3  50000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 4  50000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
#
#                            homepage        id original_language  \
# ...
