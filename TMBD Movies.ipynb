# %% [markdown]
# Imports

# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
import os
os.makedirs('Data/',exist_ok=True) # Confirm folder created
os.listdir("Data/")
# Out:
# ['title_basics_cleaned.csv.gz',
#  'title.basics.tsv.gz',
#  'ratings_cleaned.csv.gz',
#  'akas_cleaned.csv.gz',
#  'title.ratings.tsv.gz',
#  'title-akas-us-only.csv']

# %%
title_aka = pd.read_csv('Data/title-akas-us-only.csv')
title_aka.head()
# Out:
# /var/folders/2t/ty56pl2n2m7dps7c3szdtl7w0000gn/T/ipykernel_3894/1523512273.py:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   title_aka = pd.read_csv('Data/title-akas-us-only.csv')
#      titleId  ordering                   title region language        types  \
# 0  tt0000001         6              Carmencita     US       \N  imdbDisplay
# 1  tt0000002         7  The Clown and His Dogs     US       \N           \N
# 2  tt0000005        10        Blacksmith Scene     US       \N  imdbDisplay
# 3  tt0000005         1     Blacksmithing Scene     US       \N  alternative
# 4  tt0000005         6     Blacksmith Scene #1     US       \N  alternative
#
#               attributes isOriginalTitle
# 0                     \N               0
# 1  literal English title               0
# 2                     \N               0
# 3                     \N               0
# 4                     \N               0

# %%
title_basics = pd.read_csv('Data/title.basics.tsv.gz', sep='\t', low_memory=False)
title_basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
title_ratings = pd.read_csv('Data/title.ratings.tsv.gz', sep='\t', low_memory=False)
title_ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1992
# 1  tt0000002            5.8       268
# 2  tt0000003            6.5      1878
# 3  tt0000004            5.5       177
# 4  tt0000005            6.2      2662

# %% [markdown]
# ### Preprocessing for AKAs:

# %%
title_aka = title_aka[title_aka['region'].str.contains('US')]

# %%
title_aka['region'] = title_aka['region'].fillna('')

# %%
title_aka.replace({'\\N': np.nan}, inplace=True)

# %%
title_aka.head()
# Out:
#      titleId  ordering                   title region language        types  \
# 0  tt0000001         6              Carmencita     US      NaN  imdbDisplay
# 1  tt0000002         7  The Clown and His Dogs     US      NaN          NaN
# 2  tt0000005        10        Blacksmith Scene     US      NaN  imdbDisplay
# 3  tt0000005         1     Blacksmithing Scene     US      NaN  alternative
# 4  tt0000005         6     Blacksmith Scene #1     US      NaN  alternative
#
#               attributes isOriginalTitle
# 0                    NaN               0
# 1  literal English title               0
# 2                    NaN               0
# 3                    NaN               0
# 4                    NaN               0

# %% [markdown]
# ### Preprocessing for Title Basics:

# %%
title_basics.isna().sum()
# Out:
# tconst             0
# titleType          0
# primaryTitle      11
# originalTitle     11
# isAdult            0
# startYear          0
# endYear            0
# runtimeMinutes     0
# genres            18
# dtype: int64

# %%
title_basics.replace({'\\N': np.nan}, inplace=True)

# %%
title_basics['startYear'] = title_basics['startYear'].astype(float)

# %%
is_documentary = title_basics['genres'].str.contains('Documentary', case=False)

# %%
title_basics.replace({'\\N': np.nan}, inplace=True)

# %%
title_basics = title_basics.dropna(subset=['runtimeMinutes', 'genres'])

# %%
title_basics = title_basics[title_basics['titleType'] == 'movie']

# %%
title_basics = title_basics[(title_basics['startYear'] >= 2000) & (title_basics['startYear'] <= 2021)]

# %%
title_basics.head()
# Out:
#           tconst titleType                                       primaryTitle  \
# 13081  tt0013274     movie                        Istoriya grazhdanskoy voyny
# 34800  tt0035423     movie                                     Kate & Leopold
# 61112  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 67486  tt0068865     movie                                Lives of Performers
# 67664  tt0069049     movie                         The Other Side of the Wind
#
#                                    originalTitle isAdult  startYear endYear  \
# 13081                Istoriya grazhdanskoy voyny       0     2021.0     NaN
# 34800                             Kate & Leopold       0     2001.0     NaN
# 61112  El tango del viudo y su espejo deformante       0     2020.0     NaN
# 67486                        Lives of Performers       0     2016.0     NaN
# 67664                 The Other Side of the Wind       0     2018.0     NaN
#
#       runtimeMinutes                  genres
# 13081             94             Documentary
# 34800            118  Comedy,Fantasy,Romance
# 61112             70                   Drama
# 67486             90                   Drama
# 67664            122                   Drama

# %% [markdown]
# ### Preprocessing for movie titles ratings:

# %%
title_ratings.replace({'\\N': np.nan}, inplace=True)

# %%
title_aka.head()
# Out:
#      titleId  ordering                   title region language        types  \
# 0  tt0000001         6              Carmencita     US      NaN  imdbDisplay
# 1  tt0000002         7  The Clown and His Dogs     US      NaN          NaN
# 2  tt0000005        10        Blacksmith Scene     US      NaN  imdbDisplay
# 3  tt0000005         1     Blacksmithing Scene     US      NaN  alternative
# 4  tt0000005         6     Blacksmith Scene #1     US      NaN  alternative
#
#               attributes isOriginalTitle
# 0                    NaN               0
# 1  literal English title               0
# 2                    NaN               0
# 3                    NaN               0
# 4                    NaN               0

# %% [markdown]
# ### Converting to CSV

# %%
title_aka.to_csv("Data/akas_cleaned.csv.gz", compression='gzip', index=False)
title_aka.head()
# Out:
#      titleId  ordering                   title region language        types  \
# 0  tt0000001         6              Carmencita     US      NaN  imdbDisplay
# 1  tt0000002         7  The Clown and His Dogs     US      NaN          NaN
# 2  tt0000005        10        Blacksmith Scene     US      NaN  imdbDisplay
# 3  tt0000005         1     Blacksmithing Scene     US      NaN  alternative
# 4  tt0000005         6     Blacksmith Scene #1     US      NaN  alternative
#
#               attributes isOriginalTitle
# 0                    NaN               0
# 1  literal English title               0
# 2                    NaN               0
# 3                    NaN               0
# 4                    NaN               0

# %%
title_basics.to_csv("Data/title_basics_cleaned.csv.gz", compression='gzip', index=False)
title_basics.head()
# Out:
#           tconst titleType                                       primaryTitle  \
# 13081  tt0013274     movie                        Istoriya grazhdanskoy voyny
# 34800  tt0035423     movie                                     Kate & Leopold
# 61112  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 67486  tt0068865     movie                                Lives of Performers
# 67664  tt0069049     movie                         The Other Side of the Wind
#
#                                    originalTitle isAdult  startYear endYear  \
# 13081                Istoriya grazhdanskoy voyny       0     2021.0     NaN
# 34800                             Kate & Leopold       0     2001.0     NaN
# 61112  El tango del viudo y su espejo deformante       0     2020.0     NaN
# 67486                        Lives of Performers       0     2016.0     NaN
# 67664                 The Other Side of the Wind       0     2018.0     NaN
#
#       runtimeMinutes                  genres
# 13081             94             Documentary
# 34800            118  Comedy,Fantasy,Romance
# 61112             70                   Drama
# 67486             90                   Drama
# 67664            122                   Drama

# %%
title_ratings.to_csv("Data/ratings_cleaned.csv.gz", compression='gzip', index=False)
title_ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1992
# 1  tt0000002            5.8       268
# 2  tt0000003            6.5      1878
# 3  tt0000004            5.5       177
# 4  tt0000005            6.2      2662

# %%
title_aka = pd.read_csv("Data/akas_cleaned.csv.gz", low_memory=False)
title_aka.head()
# Out:
#      titleId  ordering                   title region language        types  \
# 0  tt0000001         6              Carmencita     US      NaN  imdbDisplay
# 1  tt0000002         7  The Clown and His Dogs     US      NaN          NaN
# 2  tt0000005        10        Blacksmith Scene     US      NaN  imdbDisplay
# 3  tt0000005         1     Blacksmithing Scene     US      NaN  alternative
# 4  tt0000005         6     Blacksmith Scene #1     US      NaN  alternative
#
#               attributes  isOriginalTitle
# 0                    NaN              0.0
# 1  literal English title              0.0
# 2                    NaN              0.0
# 3                    NaN              0.0
# 4                    NaN              0.0

# %%
title_basics = pd.read_csv("Data/title_basics_cleaned.csv.gz", low_memory=False)
title_basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0013274     movie                        Istoriya grazhdanskoy voyny
# 1  tt0035423     movie                                     Kate & Leopold
# 2  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 3  tt0068865     movie                                Lives of Performers
# 4  tt0069049     movie                         The Other Side of the Wind
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                Istoriya grazhdanskoy voyny        0     2021.0      NaN
# 1                             Kate & Leopold        0     2001.0      NaN
# 2  El tango del viudo y su espejo deformante        0     2020.0      NaN
# 3                        Lives of Performers        0     2016.0      NaN
# 4                 The Other Side of the Wind        0     2018.0      NaN
#
#    runtimeMinutes                  genres
# 0              94             Documentary
# 1             118  Comedy,Fantasy,Romance
# 2              70                   Drama
# 3              90                   Drama
# 4             122                   Drama

# %%
title_ratings = pd.read_csv("Data/ratings_cleaned.csv.gz", low_memory=False)
title_ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1992
# 1  tt0000002            5.8       268
# 2  tt0000003            6.5      1878
# 3  tt0000004            5.5       177
# 4  tt0000005            6.2      2662

# %%
keepers = title_basics['tconst'].isin(title_aka['titleId'])
keepers
# Out:
# 0         False
# 1          True
# 2          True
# 3          True
# 4          True
#           ...
# 211623    False
# 211624    False
# 211625    False
# 211626    False
# 211627    False
# Name: tconst, Length: 211628, dtype: bool

# %%
basics = title_basics[keepers]
basics
# Out:
#            tconst titleType  \
# 1       tt0035423     movie
# 2       tt0062336     movie
# 3       tt0068865     movie
# 4       tt0069049     movie
# 6       tt0088751     movie
# ...           ...       ...
# 211613  tt9915436     movie
# 211615  tt9915872     movie
# 211618  tt9916170     movie
# 211620  tt9916190     movie
# 211622  tt9916362     movie
#
#                                              primaryTitle  \
# 1                                          Kate & Leopold
# 2       The Tango of the Widower and Its Distorting Mi...
# 3                                     Lives of Performers
# 4                              The Other Side of the Wind
# 6                                       The Naked Monster
# ...                                                   ...
# 211613                                  Vida em Movimento
# 211615                               The Last White Witch
# 211618                                      The Rehearsal
# 211620                                          Safeguard
# 211622                                              Coven
#
#                                     originalTitle  isAdult  startYear  \
# 1                                  Kate & Leopold        0     2001.0
# 2       El tango del viudo y su espejo deformante        0     2020.0
# 3                             Lives of Performers        0     2016.0
# 4                      The Other Side of the Wind        0     2018.0
# 6                               The Naked Monster        0     2005.0
# ...                                           ...      ...        ...
# 211613                          Vida em Movimento        0     2019.0
# 211615              Boku no kanojo wa mahoutsukai        0     2019.0
# 211618                                   O Ensaio        0     2019.0
# 211620                                  Safeguard        0     2020.0
# 211622                                   Akelarre        0     2020.0
#
#         endYear  runtimeMinutes                     genres
# 1           NaN             118     Comedy,Fantasy,Romance
# 2           NaN              70                      Drama
# 3           NaN              90                      Drama
# 4           NaN             122                      Drama
# 6           NaN             100       Comedy,Horror,Sci-Fi
# ...         ...             ...                        ...
# 211613      NaN              70                Documentary
# 211615      NaN              97       Comedy,Drama,Fantasy
# 211618      NaN              51                      Drama
# 211620      NaN              95  Action,Adventure,Thriller
# 211622      NaN              92              Drama,History
#
# [114442 rows x 9 columns]

# %%
## Save current dataframe to file.
basics.to_csv("Data/title_basics_1.csv.gz",compression='gzip',index=False)

# %%
# Open saved file and preview again
basics = pd.read_csv("Data/title_basics_1.csv.gz", low_memory = False)
basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0068865     movie                                Lives of Performers
# 3  tt0069049     movie                         The Other Side of the Wind
# 4  tt0088751     movie                                  The Naked Monster
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0     2001.0      NaN
# 1  El tango del viudo y su espejo deformante        0     2020.0      NaN
# 2                        Lives of Performers        0     2016.0      NaN
# 3                 The Other Side of the Wind        0     2018.0      NaN
# 4                          The Naked Monster        0     2005.0      NaN
#
#    runtimeMinutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2              90                   Drama
# 3             122                   Drama
# 4             100    Comedy,Horror,Sci-Fi
